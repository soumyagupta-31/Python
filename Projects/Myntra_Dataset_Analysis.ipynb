# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Myntra dataset.csv')

df.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta with Skirt    FASHION DWAR     0.0             0
#
#    marked_price  discounted_price  \
# 0          1295               828
# 1          1299               584
# 2          1999              1599
# 3           599               539
# 4          2899              2899
#
#                                         product_link
# 0  wallets/lino-perros/lino-perros-women-peach-co...
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...
# 2  kurtas/biba/biba-women-off-white--black-printe...
# 3  tshirts/anthrilo/anthrilo-girls-white-floral-p...
# 4  kurta-sets/fashion-dwar/fashion-dwar-women-mul...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0e566b70f572> in <cell line: 0>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168029 entries, 0 to 168028
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   product_name      168029 non-null  object
#  1   brand_name        168029 non-null  object
#  2   rating            168029 non-null  float64
#  3   rating_count      168029 non-null  int64
#  4   marked_price      168029 non-null  int64
#  5   discounted_price  168029 non-null  int64
#  6   product_link      168029 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 9.0+ MB

# %%
df.isnull().sum()
# Out:
# product_name        0
# brand_name          0
# rating              0
# rating_count        0
# marked_price        0
# discounted_price    0
# product_link        0
# dtype: int64

# %%
df['product_name'] = df['product_name'].str.strip().str.title()
df['brand_name'] = df['brand_name'].str.strip().str.title()
df.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-Line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-Shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta With Skirt    Fashion Dwar     0.0             0
#
#    marked_price  discounted_price  \
# 0          1295               828
# 1          1299               584
# 2          1999              1599
# 3           599               539
# 4          2899              2899
#
#                                         product_link
# 0  wallets/lino-perros/lino-perros-women-peach-co...
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...
# 2  kurtas/biba/biba-women-off-white--black-printe...
# 3  tshirts/anthrilo/anthrilo-girls-white-floral-p...
# 4  kurta-sets/fashion-dwar/fashion-dwar-women-mul...

# %%
df['product_id'] = df['product_link'].str.split('/').str[-2]
df.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-Line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-Shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta With Skirt    Fashion Dwar     0.0             0
#
#    marked_price  discounted_price  \
# 0          1295               828
# 1          1299               584
# 2          1999              1599
# 3           599               539
# 4          2899              2899
#
#                                         product_link product_id
# 0  wallets/lino-perros/lino-perros-women-peach-co...   18070682
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...   12548958
# 2  kurtas/biba/biba-women-off-white--black-printe...   13446092
# 3  tshirts/anthrilo/anthrilo-girls-white-floral-p...   18017006
# 4  kurta-sets/fashion-dwar/fashion-dwar-women-mul...   18015232

# %%
df['category'] = df['product_link'].str.split('/').str[0]
df.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-Line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-Shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta With Skirt    Fashion Dwar     0.0             0
#
#    marked_price  discounted_price  \
# 0          1295               828
# 1          1299               584
# 2          1999              1599
# 3           599               539
# 4          2899              2899
#
#                                         product_link product_id    category
# 0  wallets/lino-perros/lino-perros-women-peach-co...   18070682     wallets
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...   12548958  flip-flops
# 2  kurtas/biba/biba-women-off-white--black-printe...   13446092      kurtas
# 3  tshirts/anthrilo/anthrilo-girls-white-floral-p...   18017006     tshirts
# 4  kurta-sets/fashion-dwar/fashion-dwar-women-mul...   18015232  kurta-sets

# %%
df['total_revenue'] = df['rating_count'] * df['discounted_price']
df.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-Line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-Shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta With Skirt    Fashion Dwar     0.0             0
#
#    marked_price  discounted_price  \
# 0          1295               828
# 1          1299               584
# 2          1999              1599
# 3           599               539
# 4          2899              2899
#
#                                         product_link product_id    category  \
# 0  wallets/lino-perros/lino-perros-women-peach-co...   18070682     wallets
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...   12548958  flip-flops
# 2  kurtas/biba/biba-women-off-white--black-printe...   13446092      kurtas
# 3  tshirts/anthrilo/anthrilo-girls-white-floral-p...   18017006     tshirts
# 4  kurta-sets/fashion-dwar/fashion-dwar-women-mul...   18015232  kurta-sets
#
#    total_revenue  discount
# 0              0       467
# 1          44384       715
# 2         105534       400
# 3              0        60
# 4              0         0

# %%
#discount
df['discount'] = df['marked_price'] - df['discounted_price']
df.head()
# Out:
#                      product_name      brand_name  rating  rating_count  \
# 0   Croc Textured Two Fold Wallet     Lino Perros     0.0             0
# 1             Men Striped Sliders  Mast & Harbour     4.0            76
# 2            Printed A-Line Kurta            Biba     4.3            66
# 3    Girls Floral Printed T-Shirt        Anthrilo     0.0             0
# 4  Women Printed Kurta With Skirt    Fashion Dwar     0.0             0
#
#    marked_price  discounted_price  \
# 0          1295               828
# 1          1299               584
# 2          1999              1599
# 3           599               539
# 4          2899              2899
#
#                                         product_link product_id    category  \
# 0  wallets/lino-perros/lino-perros-women-peach-co...   18070682     wallets
# 1  flip-flops/mast--harbour/mast--harbour-men-nav...   12548958  flip-flops
# 2  kurtas/biba/biba-women-off-white--black-printe...   13446092      kurtas
# 3  tshirts/anthrilo/anthrilo-girls-white-floral-p...   18017006     tshirts
# 4  kurta-sets/fashion-dwar/fashion-dwar-women-mul...   18015232  kurta-sets
#
#    total_revenue  discount
# 0            828       467
# 1            660       715
# 2           1665       400
# 3            539        60
# 4           2899         0

# %%
#discounted price vs rating
plt.figure(figsize=(10, 6))

# Customize color, marker, and transparency
plt.scatter(df['rating'], df['discounted_price'],
            color='royalblue', marker='o', alpha=0.6, edgecolor='black')

# Add grid, labels, and title
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Discounted Price (₹)', fontsize=12)
plt.title('Discounted Price vs Rating', fontsize=14)
plt.tight_layout()

plt.show()

# %%
sns.scatterplot(data = df, x= 'discount', y= 'rating')

plt.title('Discount vs Rating')
plt.show()

# %%
#find top 10 brands by product count

top_brands = df['brand_name'].value_counts().head(10)
top_brands
# Out:
# brand_name
# Roadster                 4982
# Mast & Harbour           2640
# Dressberry               2330
# H&M                      2188
# Max                      2045
# Anouk                    1962
# Hrx By Hrithik Roshan    1922
# Here&Now                 1816
# Puma                     1805
# Mango                    1741
# Name: count, dtype: int64

# %%
#find top 10 brands by average discount

top_avg_dis = df.groupby('brand_name')['discount'].mean().sort_values(ascending=False).head(10)
top_avg_dis
# Out:
# brand_name
# Swatika                     22500.000000
# Earnshaw                    20201.346154
# Bottega Veneta              17245.000000
# Morkanth Jewellery          14000.000000
# Swiss Military By Chrono    12375.000000
# White Fire                  12277.657143
# Nakkashi                    12232.000000
# Justanned                   12044.450000
# National Geographic         12000.000000
# Mini                        11830.000000
# Name: discount, dtype: float64

# %%
#find the top 10 most reviewed products

top_reviewed = df.sort_values(by = 'rating_count', ascending = False).head(10)
top_reviewed [['product_name','brand_name','rating_count']]
# Out:
#                               product_name             brand_name  \
# 33432            Unisex Skin Care Gift Set               Biotique
# 59424               Kajal & Bold Liner Set             Maybelline
# 128773           Unisex Skin Care Gift Set               Biotique
# 128808           Unisex Skin Care Gift Set               Biotique
# 104447  Printed Cotton Pure Cotton T-Shirt  Hrx By Hrithik Roshan
# 108846                  Skin Care Gift Set               Biotique
# 75597        Toner-Cream-Serum-Night Cream               Biotique
# 75647        Toner-Cream-Serum-Night Cream               Biotique
# 160063        Set Of Foundation & Eyeliner             Maybelline
# 83734            Set Of Eyeliner & Mascara             Maybelline
#
#         rating_count
# 33432          55900
# 59424          54600
# 128773         51000
# 128808         51000
# 104447         49300
# 108846         39100
# 75597          38600
# 75647          38600
# 160063         37000
# 83734          36200

# %%
# find the products with highest discount

top_discount = df.sort_values(by = 'discount', ascending = False).head(10)
top_discount [['product_name', 'brand_name', 'discount']]
# Out:
#                                              product_name          brand_name  \
# 27039                              Lord Krishna Showpiece         Ecraftindia
# 56197                         Durga Maa On Lion Showpiece         Ecraftindia
# 117809  Men Stainless Steel Straps Multi Function Auto...            Earnshaw
# 117817  Men Stainless Steel Straps Multi Function Auto...            Earnshaw
# 116473  Men Stainless Steel Straps Multi Function Auto...            Earnshaw
# 18316   Textured 360-Degree Rotation Hard-Sided Trolle...              Safari
# 25265             Gold-Plated Stone-Studded Jewellery Set  Silvermerc Designs
# 24736                           Gold Plated Jewellery Set  Silvermerc Designs
# 15422                           Gold Plated Jewellery Set  Silvermerc Designs
# 116276  Men Leather Straps Multi Function Automatic Mo...            Earnshaw
#
#         discount
# 27039      68400
# 56197      43200
# 117809     25580
# 117817     25580
# 116473     25580
# 18316      23758
# 25265      23600
# 24736      23200
# 15422      23200
# 116276     22780
